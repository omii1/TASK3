# %% [markdown]
# # NAME: OMKAR KHARKAR

# %% [markdown]
# # For the given ‘Iris’ dataset, create Decision Tree classifier and visualize it graphically .

# %%
# IMPORTING NECESSARY  LIBRARY
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets

# %%
# LOADING DATASET 
iris = datasets.load_iris()
df = pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
sns.pairplot(data=df)

# %% [markdown]
# # SPLITING THE DATASET

# %%
x=df
y=iris.target

# %% [markdown]
# # TRAINING DATASET

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# # IMPORTING DECISIONTREECLASSIFIER

# %%
from sklearn.tree  import DecisionTreeClassifier

# %%
d = DecisionTreeClassifier(max_depth=3)
d.fit(x_train,y_train)
print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %%
y_pred=d.predict(x_test)

# %% [markdown]
# # COMPARING BETWEEN ACTUAL & PREDICTING VALUE

# %%
df=pd.DataFrame({"Actual":y_test,"predicted":y_pred})
df.head(10)
# Out:
#    Actual  predicted
# 0       1          1
# 1       0          0
# 2       2          2
# 3       1          1
# 4       1          1
# 5       0          0
# 6       1          1
# 7       2          2
# 8       1          1
# 9       1          1

# %% [markdown]
# # from sklearn.external.six import StringIO DOSE NOT WORK YOU CAN USE BELOW COMMAND INSTEAD OF IT.

# %%
pip install six

# %% [markdown]
# # VISUALIZING THE GRAPH

# %%
# Import necessary libraries for graph viz
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(d, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
